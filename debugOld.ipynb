# %%
import datetime
from aiohttp import ClientSession, CookieJar, TraceConfig

from custom_components.brunata_online import BrunataClient


async def on_request_headers_sent(session, trace_config_ctx, params):
    print("-----------HEADERS SENT-----------")
    print(f"{params.method} {params.url}")
    for k, v in params.headers.items():
        print(f"{k}: {v}")
    print("-------------------------------")
trace_config = TraceConfig()
trace_config.on_request_headers_sent.append(on_request_headers_sent)

session = ClientSession(cookie_jar=CookieJar(unsafe=True), trace_configs=[trace_config])

# %%
client = BrunataClient("thoms_hoffmann@me.com", "Something4me", session, "en", True)

# %%
allocation_units = await client._get_allocation_units()
# Out:
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): online.brunata.com:443
# /usr/local/lib/python3.13/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'host.docker.internal'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# DEBUG:urllib3.connectionpool:https://online.brunata.com:443 "GET /online-auth-webservice/v1/rest/authorize?client_id=e1d10965-78dc-4051-a1e5-251483e74d03&redirect_uri=https%3A%2F%2Fonline.brunata.com%2Fauth-response&scope=e1d10965-78dc-4051-a1e5-251483e74d03+offline_access&response_type=code&code_challenge=vqaYFO1FPGFJ3MScCXJGkOxYla9tIpc97PaMeBWxgeg&code_challenge_method=S256 HTTP/1.1" 307 0
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): brunatab2cprod.b2clogin.com:443
# /usr/local/lib/python3.13/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'host.docker.internal'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# DEBUG:urllib3.connectionpool:https://brunatab2cprod.b2clogin.com:443 "GET /brunatab2cprod.onmicrosoft.com/B2C_1_signin_username/oauth2/v2.0/authorize?scope=e1d10965-78dc-4051-a1e5-251483e74d03+offline_access&response_type=code&redirect_uri=https%3A%2F%2Fonline.brunata.com%2Fauth-response&code_challenge_method=S256&client_id=e1d10965-78dc-4051-a1e5-251483e74d03&code_challenge=vqaYFO1FPGFJ3MScCXJGkOxYla9tIpc97PaMeBWxgeg HTTP/1.1" 200 158261
# INFO:custom_components.brunata_online.api.brunata_api:-----------START-----------
# GET https://brunatab2cprod.b2clogin.com/brunatab2cprod.onmicrosoft.com/B2C_1_signin_username/oauth2/v2.0/authorize?scope=e1d10965-78dc-4051-a1e5-251483e74d03+offline_access&response_type=code&redirect_uri=https%3A%2F%2Fonline.brunata.com%2Fauth-response&code_challenge_method=S256&client_id=e1d10965-78dc-4051-a1e5-251483e74d03&code_challenge=vqaYFO1FPGFJ3MScCXJGkOxYla9tIpc97PaMeBWxgeg
# User-Agent: python-requests/2.32.5
# Accept-Encoding: gzip, deflate
# Accept: */*
# Connection: keep-alive
#
# None
# DEBUG:custom_components.brunata_online.api.brunata_api:Transaction ID: StateProperties=eyJUSUQiOiJlYjgwMjJjMS0wYTcyLTQzMjItOWUxZi0wZDg5ZDM4Y2RhNzEifQ
# /usr/local/lib/python3.13/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'host.docker.internal'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# DEBUG:urllib3.connectionpool:https://brunatab2cprod.b2clogin.com:443 "POST /brunatab2cprod.onmicrosoft.com/B2C_1_signin_username/SelfAsserted?tx=StateProperties%3DeyJUSUQiOiJlYjgwMjJjMS0wYTcyLTQzMjItOWUxZi0wZDg5ZDM4Y2RhNzEifQ&p=B2C_1_signin_username HTTP/1.1" 200 136
# INFO:custom_components.brunata_online.api.brunata_api:-----------START-----------
# POST https://brunatab2cprod.b2clogin.com/brunatab2cprod.onmicrosoft.com/B2C_1_signin_username/SelfAsserted?tx=StateProperties%3DeyJUSUQiOiJlYjgwMjJjMS0wYTcyLTQzMjItOWUxZi0wZDg5ZDM4Y2RhNzEifQ&p=B2C_1_signin_username
# User-Agent: python-requests/2.32.5
# Accept-Encoding: gzip, deflate
# Accept: */*
# Connection: keep-alive
# Referer: https://brunatab2cprod.b2clogin.com/brunatab2cprod.onmicrosoft.com/B2C_1_signin_username/oauth2/v2.0/authorize?scope=e1d10965-78dc-4051-a1e5-251483e74d03+offline_access&response_type=code&redirect_uri=https%3A%2F%2Fonline.brunata.com%2Fauth-response&code_challenge_method=S256&client_id=e1d10965-78dc-4051-a1e5-251483e74d03&code_challenge=vqaYFO1FPGFJ3MScCXJGkOxYla9tIpc97PaMeBWxgeg
# X-Csrf-Token: R1NGZVdJT05BUjRMWExoMExvL3NxWkd6UCt0WlZXQk9GWnFXT1JmSExMNkFZeUFINnhqc1JZRnkwVm53aFNmN29VaWg5OEtubkhyOGhMVmhQKzJlY2c9PTsyMDI1LTEyLTI4VDExOjE0OjQ4LjU0Njk4MzhaO3Z6TDFMS3E3bDVvczBFVFluWGRmZ3c9PTt7Ik9yY2hlc3RyYXRpb25TdGVwIjoxfQ==
# X-Requested-With: XMLHttpRequest
# Host: brunatab2cprod.b2clogin.com
# Cookie: x-ms-cpim-csrf=R1NGZVdJT05BUjRMWExoMExvL3NxWkd6UCt0WlZXQk9GWnFXT1JmSExMNkFZeUFINnhqc1JZRnkwVm53aFNmN29VaWg5OEtubkhyOGhMVmhQKzJlY2c9PTsyMDI1LTEyLTI4VDExOjE0OjQ4LjU0Njk4MzhaO3Z6TDFMS3E3bDVvczBFVFluWGRmZ3c9PTt7Ik9yY2hlc3RyYXRpb25TdGVwIjoxfQ==; x-ms-cpim-cache|wska63ikikoehw2j04zacq_0=m1.HGpkmJdTXsd7ht/k.LVX4RPbVxrt4r+qQ5t5blA==.0....; x-ms-cpim-trans=
# Content-Length: 83
# Content-Type: application/x-www-form-urlencoded
#
# request_type=RESPONSE&logonIdentifier=thoms_hoffmann%40me.com&password=Something4me
# /usr/local/lib/python3.13/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'host.docker.internal'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# DEBUG:urllib3.connectionpool:https://brunatab2cprod.b2clogin.com:443 "GET /brunatab2cprod.onmicrosoft.com/B2C_1_signin_username/api/CombinedSigninAndSignup/confirmed?rememberMe=False&csrf_token=R1NGZVdJT05BUjRMWExoMExvL3NxWkd6UCt0WlZXQk9GWnFXT1JmSExMNkFZeUFINnhqc1JZRnkwVm53aFNmN29VaWg5OEtubkhyOGhMVmhQKzJlY2c9PTsyMDI1LTEyLTI4VDExOjE0OjQ4LjU0Njk4MzhaO3Z6TDFMS3E3bDVvczBFVFluWGRmZ3c9PTt7Ik9yY2hlc3RyYXRpb25TdGVwIjoxfQ%3D%3D&tx=StateProperties%3DeyJUSUQiOiJlYjgwMjJjMS0wYTcyLTQzMjItOWUxZi0wZDg5ZDM4Y2RhNzEifQ&p=B2C_1_signin_username HTTP/1.1" 302 933
# INFO:custom_components.brunata_online.api.brunata_api:-----------START-----------
# GET https://brunatab2cprod.b2clogin.com/brunatab2cprod.onmicrosoft.com/B2C_1_signin_username
_UBp3vU4WGech1i8ctUjnzDmmNqE9MlRAMM9tm9TzoXE_xYpEXV7TlEBM8zpy3xqU_BYgSn_6RWPo8TiwVqoLS6D3OVPI7qGSkJJ4my8etQcnSLk2K3W5_hoFGzvLumj0kG2DB9SeLZXcTTZeL-FSZQioqtXuva4JzjxpkLezy627cTdDSFOaeiiyBiEVCvA.KWCa2cowIbEpSZ5kbfNyeA
# /usr/local/lib/python3.13/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'host.docker.internal'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# DEBUG:urllib3.connectionpool:https://brunatab2cprod.b2clogin.com:443 "POST /brunatab2cprod.onmicrosoft.com/B2C_1_signin_username/oauth2/v2.0/token HTTP/1.1" 200 2934
# -----------HEADERS SENT-----------
# GET https://online.brunata.com/online-webservice/v1/rest/consumer/superallocationunits
# Host: online.brunata.com
# Authorization: Bearer eyJhbGciOiJSUzI1NiIsImtpZCI6Ilg1ZVhrNHh5b2pORnVtMWtsMll0djhkbE5QNC1jNTdkTzZRR1RWQndhTmsiLCJ0eXAiOiJKV1QifQ.....i2RqSJ6jGed0UmvcHD6mn8o-dyEqv1thZtJMld-3FS_cWBoJzX2VjJ8GxYcN0D2S_sPlRbVpKfbxPycGou6Z-Qd_wMSXQjhgaoe9RVGB0iRN_Mx1BOK17qDain8fn9ehlR1WlNLZvbXahJcHAck7SfDsfacrFoEFRIq4M_hWzoJfnk8nEDOs_9qBmMENG6qxcyUFoRFf3o60CLZdPsKiDihNMn1clkOaDW2sviNglIp3nKV4zueY5DEIk5ygS01mWajG9hfk034b3S56DBbDp-LX9dNQcKKmNKSTziKBVUobUOf0COsRtgPoHoMVZ_st0LK8uSFG0xD3wtZ43NSMhw
# User-Agent: Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36         (KHTML, like Gecko) Chrome/126.0.0.0 Safari/537.36 Edg/126.0.0.0
# Sec-Ch-Ua: "Not/A)Brand";v="8", "Chromium";v="126", "Microsoft Edge";v="126"
# Sec-Ch-Ua-Mobile: ?0
# Sec-Ch-Ua-Platform: "Windows"
# Accept-Encoding: gzip, deflate, br, zstd
# Accept-Language: en
# Connection: keep-alive
# Accept: */*
# -------------------------------

# %%
configuration = await client._get_configuration()

# %%
meter_config = await client._get_meters()

# %%
start_time = datetime.datetime(2022, 8,1,0,0,0)
end_time = datetime.datetime(2022, 9,1,0,0,0)
f"{start_time.isoformat()}.000Z | {end_time.isoformat()}.000Z"

# %%
#await client.connect()
meters = await client.get_meters()

# %%
from custom_components.brunata_online.api.const import Consumption, Interval

consumption = await client.get_consumption(start_time, end_time, Consumption.WATER, "K", Interval.DAY)

# %%
#import json

#json.dumps([r.model_dump_json() for r in consumption])

# %%
{'Cache-Control': 'no-store, must-revalidate, no-cache', 'Content-Type': 'text/html; charset=utf-8', 'Location': 'https://online.brunata.com/auth-response?code=eyJraWQiOiJjcGltY29yZV8wOTI1MjAxNSIsInZlciI6IjEuMCIsInppcCI6IkRlZmxhdGUiLCJzZXIiOiIxLjAifQ..oyNpIa80hix_IEDK._FWkr4bxg2ONv6sAWs9H